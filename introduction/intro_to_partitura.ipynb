# %% [markdown]
# # The Partitura Package
#
# partitura is python 3 package for symbolic music processing developed and maintained at CP/JKU (and otther contributors). It's intended to give a lightweight music representations that makes many score properties easily accessible for specific tasks. Furthermore it's a very useful I/O utility to parse computer formats of symbolic music such as MusicXML / MIDI.
#
# The repo can be found here (stable = main branch, bleeding edge = develop): https://github.com/CPJKU/partitura
#
# Documentation can be found here: https://partitura.readthedocs.io/en/latest/
#
# Extended tutorial notebooks are here: https://cpjku.github.io/partitura_tutorial/

# %% [markdown]
# # The part object
#
# The ```part``` object is the central object of partitura. It contains a score.
# - it is a timeline object
# - time is measured in divs
# - its elements are timed objects, i.e. they have a starting time and an ending time
# - external score files are loaded into a part
# - parts can be exported into score files
# - it contains many useful methods related to its properties

# %%
# Uncomment these lines if the kernel keeps crashing
# See https://stackoverflow.com/a/53014308
# import os
# os.environ['KMP_DUPLICATE_LIB_OK']='True'

import partitura as pt
path_to_musicxml = pt.EXAMPLE_MUSICXML
score = pt.load_musicxml(path_to_musicxml)
part = score[0]
print(part.pretty())
# what do we need to modify to see a somewhat pretty part?
# what do we see here?
# Out:
# Part id="P1" name="Piano"
#  │
#  ├─ TimePoint t=0 quarter=12
#  │   │
#  │   └─ starting objects
#  │       │
#  │       ├─ 0--48 Measure number=1 name=1
#  │       ├─ 0--48 Note id=n01 voice=1 staff=2 type=whole pitch=A4
#  │       ├─ 0--48 Page number=1
#  │       ├─ 0--24 Rest id=r01 voice=2 staff=1 type=half
#  │       ├─ 0--48 System number=1
#  │       └─ 0-- TimeSignature 4/4
#  │
#  ├─ TimePoint t=24 quarter=12
#  │   │
#  │   ├─ ending objects
#  │   │   │
#  │   │   └─ 0--24 Rest id=r01 voice=2 staff=1 type=half
#  │   │
#  │   └─ starting objects
#  │       │
#  │       ├─ 24--48 Note id=n02 voice=2 staff=1 type=half pitch=C5
#  │       └─ 24--48 Note id=n03 voice=2 staff=1 type=half pitch=E5
#  │
#  └─ TimePoint t=48 quarter=12
#      │
#      └─ ending objects
#          │
#          ├─ 0--48 Measure number=1 name=1
#          ├─ 0--48 Note id=n01 voice=1 staff=2 type=whole pitch=A4
#          ├─ 24--48 Note id=n02 voice=2 staff=1 type=half pitch=C5
#          ├─ 24--48 Note id=n03 voice=2 staff=1 type=half pitch=E5
#          ├─ 0--48 Page number=1
#          └─ 0--48 System number=1

# %% [markdown]
# ![Timeline_chopin2.png](https://github.com/CPJKU/partitura_tutorial/raw/main/static/Timeline_chopin2.png)

# %% [markdown]
# ## Notes

# %%
part.notes
# Out:
# [<partitura.score.Note at 0x1da7de6aa00>,
#  <partitura.score.Note at 0x1da7de78160>,
#  <partitura.score.Note at 0x1da7de78190>]

# %%
# notes are timed objects
part.notes[0].start
# dir(part.notes[0])

# %%
# adding notes (times in divs!)
a_new_note = pt.score.Note(id='n04', step='A', octave=4, voice=1)
part.add(a_new_note, start=0, end=12)
# print(part.pretty())

# %%
# deleting notes
part.remove(a_new_note)
# print(part.pretty())

# how do you go about notes for which you don't have the corresponding object variable?

# %% [markdown]
# ## Iterating over arbitrary musical objects

# %%
for measure in part.iter_all(pt.score.Measure):
    print(measure)
# Out:
# 0--48 Measure number=1 name=1

# %%
for note in part.iter_all(pt.score.Note, include_subclasses=True, start=0, end=24):
    print(note)
# Out:
# 0--48 Note id=n01 voice=1 staff=2 type=whole pitch=A4

# %% [markdown]
# ## The note_array

# %%
# getting structured numpy array of notes from a part 
part.note_array()
# Out:
# array([(0., 4., 0., 4.,  0, 48, 69, 1, 'n01'),
#        (2., 2., 2., 2., 24, 24, 72, 2, 'n02'),
#        (2., 2., 2., 2., 24, 24, 76, 2, 'n03')],
#       dtype=[('onset_beat', '<f4'), ('duration_beat', '<f4'), ('onset_quarter', '<f4'), ('duration_quarter', '<f4'), ('onset_div', '<i4'), ('duration_div', '<i4'), ('pitch', '<i4'), ('voice', '<i4'), ('id', '<U256')])

# %%
part.note_array()[["onset_beat", "pitch"]]
# Out:
# array([(0., 69), (2., 72), (2., 76)],
#       dtype={'names': ['onset_beat', 'pitch'], 'formats': ['<f4', '<i4'], 'offsets': [0, 24], 'itemsize': 1056})

# %% [markdown]
# ## File Import

# %%
# score representation format musicXML -> lets look at a file
score = pt.load_musicxml(path_to_musicxml)

# %%
path_to_midifile = pt.EXAMPLE_MIDI
performance = pt.load_performance_midi(path_to_midifile)

# %% [markdown]
# ### excursion: what's a performed part?

# %%
performance[0].notes
# Out:
# [<partitura.performance.PerformedNote at 0x1da7ab1deb0>,
#  <partitura.performance.PerformedNote at 0x1da7ab1de50>,
#  <partitura.performance.PerformedNote at 0x1da7deb1190>]

# %% [markdown]
# ### excursion of the excursion: why isn't this a score representation?
# musical notes representation format MIDI -> lets look at a file

# %%
with open("example_data\\Chopin_op10_no3_p01.mid", 'rb') as f:
    # print(dir(f))
    for line in f:        
        print((line.hex()))
        print("---")
# Out:
# 4d54686400000006000100040fa04d54726b0000000b00ff510307a12000ff2f004d54726b0000107682b804903b2c9118803b409b189028160a
# ---
# 
# ---
# 8039409d129039271490231e46802f408458803b408b348042408c7c80394081029044391e903b2c8116902f1f850a
# ---
# 803f408550803b4083608044408740802f40856490443f8120903f30835690390b910480394081208044408564904241817a903b2d32902f1f836a803b405a803f40857880234032804240844e802f40934e90443d813490281d3290403050903821a6388038403c902f1b0a
# ---
# 903b269a7a802f40832e9038248254803b40957080384081708028401e902f1932903b2b9c5690281b32802f404690382950803b4082048040408b0c804440836a8038408a6e904539812a902f21812090402a885680404083248045408408802f408a00904544831a903b2c9140803b40877c904448822290402d0a
# ---
# 902f2214804540825e8040400a
# ---
# ...
# ---
# 902f1d8342903b118b66803b408d10803f40810c903d2a8134802f40812090391e846c8039409478902f2232903f29810c803d406e903b1a862a803b401e8023409260803f40813490231f0a
# ---
# 
# ---
# 
# ---
# 9044440a
# ---
# 80474050903d3d8148804040964a803d400a
# ---
# 802d406e904548810c9034285090402f8374804440887e8040408f1e902d265a904947815c80344050903d2d6e8045409e5a9036378152904030887e803d40894e804940877290424082728040408120903d22832480364093449040358120803d400a
# ---
# 9036279774903b3746902f30811680364046802d406e80404095529036288120803b400a
# ---
# 90403b8360804240865280404082728036408272903b2d844e90463f837490443c8912803b40832e8046408c5490423d815c90362728904035853c804440955290313128903a3882368036408120802f400a
# ---
# ...
# ---
# ...
# ---
# 90403a812a903b248268803b4086668028408c68802f408c68904237810c804040816690231a0090391f64903d208f50803940921a903f2832803d408152902f1b810c903b1d8a32803b408f0a
# ---
# ...
# ---
# ...
# ---
# 
# ---
# 90403d3290312b329034280a
# ---
# 9036278c4a804040844e804c40820e803a4078803440008031403c804640508036408a28904e4e32903a3a1e9042456490362d1e90342a0a
# ---
# 90312c3c9046398772804e4081168031403280424032803a40822c8036401e80344081208046408a78903a440a
# ---
# 904b5350903f500a
# ---
# 90313a3c9036333c90342c32904632825e804640850a
# ---
# 803f4050803a40815c803640820e803440810c803140820e804b40877c903a4332904c571490404d009031371e90463d469036357890342a83068040408356804c40812080464032803a4032803140328036408944803440874a904e550a
# ---
# 903a433290424b00903639149046493290303d329034398d1a804240813e804e408166803a4032803040648034408a009050570a
# ---
# 903a445090303a0a
# ---
# 90343814904449855a80304081348050400a
# ---
# 803a405a804440817a803640815c8034408634804640875e904c5714903a4d1e90405250903641009030410a
# ---
# 90464250903439856e8040408254803a403280304000804c40820e80464032803640810c8034409242903a4b00904e571e9042520a
# ---
# 90464e149036421e90304281349034328b5c804240468030405a803a4028804e40815c8036404680464081348034409e329050575a90444714903b3f1e902f3b0090383800904c455a903432ae0c90473e810c804440a106904438837e804740990a
# ---
# ...
# ---
# 9038218578804940872c804440862080384078802c4093129047360a
# ---
# 90331f8268903b249e0a
# ---
# 
# ---
# 
# ---
# 9038171e902816853c803b408240802f40a208903b1e28902f1281528038408976803b408102804440af729044261e90341b833890381c8a3c90422c88108044408666904028850a
# ---
# ...
# ---
# 8120b0400a
# ---
# 8a00b0400a
# ---
# ...
# ---
# ...
# ---
# 8120b0400a
# ---
# ...
# ---
# ...
# ---
# 
# ---
# 
# ---
# ...
# ---
# 50b0400a
# ---
# ...
# ---

# %% [markdown]
# ### part + performedpart + note alignment = match file

# %%
performance_m, alignment, score_m = pt.load_match("example_data\\Chopin_op10_no3_p01.match", create_score=True)

# %%
alignment
# Out:
# [{'label': 'match', 'score_id': 'n1', 'performance_id': 'n0'},
#  {'label': 'match', 'score_id': 'n2', 'performance_id': 'n2'},
#  {'label': 'match', 'score_id': 'n3', 'performance_id': 'n3'},
#  {'label': 'match', 'score_id': 'n4', 'performance_id': 'n1'},
#  {'label': 'match', 'score_id': 'n5', 'performance_id': 'n5'},
#  {'label': 'match', 'score_id': 'n6', 'performance_id': 'n4'},
#  {'label': 'match', 'score_id': 'n7', 'performance_id': 'n6'},
#  {'label': 'match', 'score_id': 'n8', 'performance_id': 'n7'},
#  {'label': 'match', 'score_id': 'n9', 'performance_id': 'n8'},
#  {'label': 'match', 'score_id': 'n10', 'performance_id': 'n9'},
#  {'label': 'match', 'score_id': 'n11', 'performance_id': 'n10'},
#  {'label': 'match', 'score_id': 'n12', 'performance_id': 'n11'},
#  {'label': 'match', 'score_id': 'n13', 'performance_id': 'n13'},
#  {'label': 'match', 'score_id': 'n14', 'performance_id': 'n14'},
#  {'label': 'match', 'score_id': 'n15', 'performance_id': 'n12'},
#  {'label': 'match', 'score_id': 'n16', 'performance_id': 'n16'},
#  {'label': 'match', 'score_id': 'n17', 'performance_id': 'n15'},
#  {'label': 'match', 'score_id': 'n18', 'performance_id': 'n17'},
#  {'label': 'match', 'score_id': 'n19', 'performance_id': 'n19'},
#  {'label': 'match', 'score_id': 'n20', 'performance_id': 'n18'},
#  {'label': 'match', 'score_id': 'n21', 'performance_id': 'n20'},
#  {'label': 'match', 'score_id': 'n22', 'performance_id': 'n21'},
#  {'label': 'match', 'score_id': 'n23', 'performance_id': 'n22'},
#  {'label': 'match', 'score_id': 'n24', 'performance_id': 'n23'},
#  {'label': 'match', 'score_id': 'n25', 'performance_id': 'n24'},
#  {'label': 'match', 'score_id': 'n26', 'performance_id': 'n25'},
#  {'label': 'match', 'score_id': 'n27', 'performance_id': 'n26'},
#  {'label': 'match', 'score_id': 'n28', 'performance_id': 'n27'},
#  {'label': 'match', 'score_id': 'n29', 'performance_id': 'n28'},
#  {'label': 'match', 'score_id': 'n30', 'performance_id': 'n29'},
#  {'label': 'match', 'score_id': 'n31', 'performance_id': 'n30'},
#  {'label': 'match', 'score_id': 'n32', 'performance_id': 'n31'},
#  {'label': 'match', 'score_id': 'n33', 'performance_id': 'n33'},
#  {'label': 'match', 'score_id': 'n34', 'performance_id': 'n34'},
#  {'label': 'match', 'score_id': 'n35', 'performance_id': 'n32'},
#  {'label': 'match', 'score_id': 'n36', 'performance_id': 'n36'},
#  {'label': 'match', 'score_id': 'n37', 'performance_id': 'n35'},
#  {'label': 'match', 'score_id': 'n38', 'performance_id': 'n37'},
#  {'label': 'match', 'score_id': 'n39', 'performance_id': 'n39'},
#  {'label': 'match', 'score_id': 'n40', 'performance_id': 'n38'},
#  {'label': 'match', 'score_id': 'n41', 'performance_id': 'n41'},
#  {'label': 'match', 'score_id': 'n42', 'performance_id': 'n40'},
#  {'label': 'match', 'score_id': 'n43', 'performance_id': 'n42'},
#  {'label': 'match', 'score_id': 'n44', 'performance_id': 'n44'},
#  {'label': 'match', 'score_id': 'n45', 'performance_id': 'n43'},
#  {'label': 'match', 'score_id': 'n46', 'performance_id': 'n45'},
#  {'label': 'match', 'score_id': 'n47', 'performance_id': 'n46'},
#  {'label': 'match', 'score_id': 'n48', 'performance_id': 'n47'},
#  {'label': 'match', 'score_id': 'n49', 'performance_id': 'n48'},
#  {'label': 'match', 'score_id': 'n50', 'performance_id': 'n49'},
#  {'label': 'match', 'score_id': 'n51', 'performance_id': 'n50'},
#  {'label': 'match', 'score_id': 'n52', 'performance_id': 'n51'},
#  {'label': 'match', 'score_id': 'n53', 'performance_id': 'n52'},
#  {'label': 'match', 'score_id': 'n54', 'performance_id': 'n54'},
#  {'label': 'match', 'score_id': 'n55', 'performance_id': 'n53'},
#  {'label': 'match', 'score_id': 'n56', 'performance_id': 'n55'},
#  {'label': 'match', 'score_id': 'n57', 'performance_id': 'n56'},
#  {'label': 'match', 'score_id': 'n58', 'performance_id': 'n57'},
#  {'label': 'match', 'score_id': 'n59', 'performance_id': 'n58'},
#  {'label': 'match', 'score_id': 'n60', 'performance_id': 'n59'},
#  {'label': 'match', 'score_id': 'n61', 'performance_id': 'n61'},
#  {'label': 'match', 'score_id': 'n62', 'performance_id': 'n60'},
#  {'label': 'match', 'score_id': 'n63', 'performance_id': 'n62'},
#  {'label': 'match', 'score_id': 'n64', 'performance_id': 'n63'},
#  {'label': 'match', 'score_id': 'n65', 'performance_id': 'n64'},
#  {'label': 'match', 'score_id': 'n66', 'performance_id': 'n65'},
#  {'label': 'match', 'score_id': 'n67', 'performance_id': 'n66'},
#  {'label': 'match', 'score_id': 'n68', 'performance_id': 'n67'},
#  {'label': 'match', 'score_id': 'n69', 'performance_id': 'n68'},
#  {'label': 'match', 'score_id': 'n70', 'performance_id': 'n69'},
#  {'label': 'match', 'score_id': 'n71', 'performance_id': 'n70'},
#  {'label': 'match', 'score_id': 'n72', 'performance_id': 'n72'},
#  {'label': 'match', 'score_id': 'n73', 'performance_id': 'n73'},
#  {'label': 'match', 'score_id': 'n74', 'performance_id': 'n71'},
#  {'label': 'match', 'score_id': 'n75', 'performance_id': 'n74'},
#  {'label': 'match', 'score_id': 'n76', 'performance_id': 'n76'},
#  {'label': 'match', 'score_id': 'n77', 'performance_id': 'n75'},
#  {'label': 'match', 'score_id': 'n78', 'performance_id': 'n77'},
#  {'label': 'match', 'score_id': 'n79', 'performance_id': 'n78'},
#  {'label': 'match', 'score_id': 'n80', 'performance_id': 'n80'},
#  {'label': 'match', 'score_id': 'n81', 'performance_id': 'n81'},
#  {'label': 'match', 'score_id': 'n82', 'performance_id': 'n79'},
#  {'label': 'match', 'score_id': 'n83', 'performance_id': 'n83'},
#  {'label': 'match', 'score_id': 'n84', 'performance_id': 'n84'},
#  {'label': 'match', 'score_id': 'n85', 'performance_id': 'n82'},
#  {'label': 'match', 'score_id': 'n86', 'performance_id': 'n85'},
#  {'label': 'match', 'score_id': 'n87', 'performance_id': 'n86'},
#  {'label': 'match', 'score_id': 'n88', 'performance_id': 'n88'},
#  {'label': 'match', 'score_id': 'n89', 'performance_id': 'n87'},
#  {'label': 'match', 'score_id': 'n90', 'performance_id': 'n89'},
#  {'label': 'match', 'score_id': 'n91', 'performance_id': 'n90'},
#  {'label': 'match', 'score_id': 'n92', 'performance_id': 'n91'},
#  {'label': 'match', 'score_id': 'n93', 'performance_id': 'n92'},
#  {'label': 'match', 'score_id': 'n94', 'performance_id': 'n94'},
#  {'label': 'match', 'score_id': 'n95', 'performance_id': 'n93'},
#  {'label': 'match', 'score_id': 'n96', 'performance_id': 'n95'},
#  {'label': 'match', 'score_id': 'n97', 'performance_id': 'n96'},
#  {'label': 'match', 'score_id': 'n98', 'performance_id': 'n98'},
#  {'label': 'match', 'score_id': 'n99', 'performance_id': 'n97'},
#  {'label': 'match', 'score_id': 'n100', 'performance_id': 'n100'},
#  {'label': 'match', 'score_id': 'n101', 'performance_id': 'n99'},
#  {'label': 'match', 'score_id': 'n102', 'performance_id': 'n101'},
#  {'label': 'match', 'score_id': 'n103', 'performance_id': 'n102'},
#  {'label': 'match', 'score_id': 'n104', 'performance_id': 'n103'},
#  {'label': 'match', 'score_id': 'n105', 'performance_id': 'n104'},
#  {'label': 'match', 'score_id': 'n106', 'performance_id': 'n106'},
#  {'label': 'match', 'score_id': 'n107', 'performance_id': 'n105'},
#  {'label': 'match', 'score_id': 'n108', 'performance_id': 'n107'},
#  {'label': 'match', 'score_id': 'n109', 'performance_id': 'n109'},
#  {'label': 'match', 'score_id': 'n110', 'performance_id': 'n108'},
#  {'label': 'match', 'score_id': 'n111', 'performance_id': 'n110'},
#  {'label': 'match', 'score_id': 'n112', 'performance_id': 'n111'},
#  {'label': 'match', 'score_id': 'n113', 'performance_id': 'n112'},
#  {'label': 'match', 'score_id': 'n114', 'performance_id': 'n114'},
#  {'label': 'match', 'score_id': 'n115', 'performance_id': 'n113'},
#  {'label': 'match', 'score_id': 'n116', 'performance_id': 'n115'},
#  {'label': 'match', 'score_id': 'n117', 'performance_id': 'n116'},
#  {'label': 'match', 'score_id': 'n118', 'performance_id': 'n117'},
#  {'label': 'match', 'score_id': 'n119', 'performance_id': 'n118'},
#  {'label': 'match', 'score_id': 'n120', 'performance_id': 'n120'},
#  {'label': 'match', 'score_id': 'n121', 'performance_id': 'n119'},
#  {'label': 'match', 'score_id': 'n122', 'performance_id': 'n121'},
#  {'label': 'match', 'score_id': 'n123', 'performance_id': 'n122'},
#  {'label': 'match', 'score_id': 'n124', 'performance_id': 'n123'},
#  {'label': 'match', 'score_id': 'n125', 'performance_id': 'n125'},
#  {'label': 'match', 'score_id': 'n126', 'performance_id': 'n124'},
#  {'label': 'match', 'score_id': 'n127', 'performance_id': 'n127'},
#  {'label': 'match', 'score_id': 'n128', 'performance_id': 'n128'},
#  {'label': 'match', 'score_id': 'n129', 'performance_id': 'n126'},
#  {'label': 'match', 'score_id': 'n130', 'performance_id': 'n130'},
#  {'label': 'match', 'score_id': 'n131', 'performance_id': 'n129'},
#  {'label': 'match', 'score_id': 'n132', 'performance_id': 'n131'},
#  {'label': 'match', 'score_id': 'n133', 'performance_id': 'n132'},
#  {'label': 'match', 'score_id': 'n134', 'performance_id': 'n133'},
#  {'label': 'match', 'score_id': 'n135', 'performance_id': 'n134'},
#  {'label': 'match', 'score_id': 'n136', 'performance_id': 'n135'},
#  {'label': 'match', 'score_id': 'n137', 'performance_id': 'n136'},
#  {'label': 'match', 'score_id': 'n138', 'performance_id': 'n138'},
#  {'label': 'match', 'score_id': 'n139', 'performance_id': 'n137'},
#  {'label': 'match', 'score_id': 'n140', 'performance_id': 'n140'},
#  {'label': 'match', 'score_id': 'n141', 'performance_id': 'n141'},
#  {'label': 'match', 'score_id': 'n142', 'performance_id': 'n139'},
#  {'label': 'match', 'score_id': 'n143', 'performance_id': 'n142'},
#  {'label': 'match', 'score_id': 'n144', 'performance_id': 'n144'},
#  {'label': 'match', 'score_id': 'n145', 'performance_id': 'n143'},
#  {'label': 'match', 'score_id': 'n146', 'performance_id': 'n146'},
#  {'label': 'match', 'score_id': 'n147', 'performance_id': 'n145'},
#  {'label': 'match', 'score_id': 'n148', 'performance_id': 'n147'},
#  {'label': 'match', 'score_id': 'n149', 'performance_id': 'n148'},
#  {'label': 'match', 'score_id': 'n150', 'performance_id': 'n150'},
#  {'label': 'match', 'score_id': 'n151', 'performance_id': 'n151'},
#  {'label': 'match', 'score_id': 'n152', 'performance_id': 'n149'},
#  {'label': 'match', 'score_id': 'n153', 'performance_id': 'n152'},
#  {'label': 'match', 'score_id': 'n154', 'performance_id': 'n153'},
#  {'label': 'match', 'score_id': 'n155', 'performance_id': 'n154'},
#  {'label': 'match', 'score_id': 'n156', 'performance_id': 'n155'},
#  {'label': 'match', 'score_id': 'n157', 'performance_id': 'n156'},
#  {'label': 'match', 'score_id': 'n158', 'performance_id': 'n158'},
#  {'label': 'match', 'score_id': 'n159', 'performance_id': 'n157'},
#  {'label': 'match', 'score_id': 'n160', 'performance_id': 'n159'},
#  {'label': 'match', 'score_id': 'n161', 'performance_id': 'n160'},
#  {'label': 'match', 'score_id': 'n162', 'performance_id': 'n161'},
#  {'label': 'match', 'score_id': 'n163', 'performance_id': 'n162'},
#  {'label': 'match', 'score_id': 'n164', 'performance_id': 'n163'},
#  {'label': 'match', 'score_id': 'n165', 'performance_id': 'n165'},
#  {'label': 'match', 'score_id': 'n166', 'performance_id': 'n167'},
#  {'label': 'match', 'score_id': 'n167', 'performance_id': 'n166'},
#  {'label': 'match', 'score_id': 'n168', 'performance_id': 'n164'},
#  {'label': 'match', 'score_id': 'n169', 'performance_id': 'n169'},
#  {'label': 'match', 'score_id': 'n170', 'performance_id': 'n168'},
#  {'label': 'match', 'score_id': 'n171', 'performance_id': 'n170'},
#  {'label': 'match', 'score_id': 'n172', 'performance_id': 'n171'},
#  {'label': 'match', 'score_id': 'n173', 'performance_id': 'n172'},
#  {'label': 'match', 'score_id': 'n174', 'performance_id': 'n174'},
#  {'label': 'match', 'score_id': 'n175', 'performance_id': 'n173'},
#  {'label': 'match', 'score_id': 'n176', 'performance_id': 'n175'},
#  {'label': 'match', 'score_id': 'n177', 'performance_id': 'n177'},
#  {'label': 'match', 'score_id': 'n178', 'performance_id': 'n178'},
#  {'label': 'match', 'score_id': 'n179', 'performance_id': 'n176'},
#  {'label': 'match', 'score_id': 'n180', 'performance_id': 'n180'},
#  {'label': 'match', 'score_id': 'n181', 'performance_id': 'n179'},
#  {'label': 'match', 'score_id': 'n182', 'performance_id': 'n181'},
#  {'label': 'match', 'score_id': 'n183', 'performance_id': 'n182'},
#  {'label': 'match', 'score_id': 'n184', 'performance_id': 'n183'},
#  {'label': 'match', 'score_id': 'n185', 'performance_id': 'n184'},
#  {'label': 'match', 'score_id': 'n186', 'performance_id': 'n185'},
#  {'label': 'match', 'score_id': 'n187', 'performance_id': 'n186'},
#  {'label': 'match', 'score_id': 'n188', 'performance_id': 'n187'},
#  {'label': 'match', 'score_id': 'n189', 'performance_id': 'n188'},
#  {'label': 'match', 'score_id': 'n190', 'performance_id': 'n189'},
#  {'label': 'match', 'score_id': 'n191', 'performance_id': 'n190'},
#  {'label': 'match', 'score_id': 'n192', 'performance_id': 'n191'},
#  {'label': 'match', 'score_id': 'n193', 'performance_id': 'n192'},
#  {'label': 'match', 'score_id': 'n194', 'performance_id': 'n194'},
#  {'label': 'match', 'score_id': 'n195', 'performance_id': 'n193'},
#  {'label': 'match', 'score_id': 'n196', 'performance_id': 'n195'},
#  {'label': 'match', 'score_id': 'n197', 'performance_id': 'n197'},
#  {'label': 'match', 'score_id': 'n198', 'performance_id': 'n198'},
#  {'label': 'match', 'score_id': 'n199', 'performance_id': 'n196'},
#  {'label': 'match', 'score_id': 'n200', 'performance_id': 'n200'},
#  {'label': 'match', 'score_id': 'n201', 'performance_id': 'n199'},
#  {'label': 'match', 'score_id': 'n202', 'performance_id': 'n201'},
#  {'label': 'match', 'score_id': 'n203', 'performance_id': 'n203'},
#  {'label': 'match', 'score_id': 'n204', 'performance_id': 'n202'},
#  {'label': 'match', 'score_id': 'n205', 'performance_id': 'n204'},
#  {'label': 'match', 'score_id': 'n206', 'performance_id': 'n205'},
#  {'label': 'match', 'score_id': 'n207', 'performance_id': 'n206'},
#  {'label': 'match', 'score_id': 'n208', 'performance_id': 'n208'},
#  {'label': 'match', 'score_id': 'n209', 'performance_id': 'n207'},
#  {'label': 'match', 'score_id': 'n210', 'performance_id': 'n209'},
#  {'label': 'match', 'score_id': 'n211', 'performance_id': 'n210'},
#  {'label': 'match', 'score_id': 'n212', 'performance_id': 'n211'},
#  {'label': 'match', 'score_id': 'n213', 'performance_id': 'n213'},
#  {'label': 'match', 'score_id': 'n214', 'performance_id': 'n212'},
#  {'label': 'match', 'score_id': 'n215', 'performance_id': 'n214'},
#  {'label': 'match', 'score_id': 'n216', 'performance_id': 'n216'},
#  {'label': 'match', 'score_id': 'n217', 'performance_id': 'n215'},
#  {'label': 'match', 'score_id': 'n218', 'performance_id': 'n218'},
#  {'label': 'match', 'score_id': 'n219', 'performance_id': 'n217'},
#  {'label': 'match', 'score_id': 'n220', 'performance_id': 'n219'},
#  {'label': 'match', 'score_id': 'n221', 'performance_id': 'n220'},
#  {'label': 'match', 'score_id': 'n222', 'performance_id': 'n222'},
#  {'label': 'match', 'score_id': 'n223', 'performance_id': 'n221'},
#  {'label': 'match', 'score_id': 'n224', 'performance_id': 'n223'},
#  {'label': 'match', 'score_id': 'n225', 'performance_id': 'n225'},
#  {'label': 'match', 'score_id': 'n226', 'performance_id': 'n224'},
#  {'label': 'match', 'score_id': 'n227', 'performance_id': 'n226'},
#  {'label': 'match', 'score_id': 'n228', 'performance_id': 'n228'},
#  {'label': 'match', 'score_id': 'n229', 'performance_id': 'n227'},
#  {'label': 'match', 'score_id': 'n230', 'performance_id': 'n229'},
#  {'label': 'match', 'score_id': 'n231', 'performance_id': 'n230'},
#  {'label': 'match', 'score_id': 'n232', 'performance_id': 'n232'},
#  {'label': 'match', 'score_id': 'n233', 'performance_id': 'n233'},
#  {'label': 'match', 'score_id': 'n234', 'performance_id': 'n231'},
#  {'label': 'match', 'score_id': 'n235', 'performance_id': 'n234'},
#  {'label': 'match', 'score_id': 'n236', 'performance_id': 'n237'},
#  {'label': 'match', 'score_id': 'n237', 'performance_id': 'n236'},
#  {'label': 'match', 'score_id': 'n238', 'performance_id': 'n235'},
#  {'label': 'match', 'score_id': 'n239', 'performance_id': 'n238'},
#  {'label': 'match', 'score_id': 'n240', 'performance_id': 'n240'},
#  {'label': 'match', 'score_id': 'n241', 'performance_id': 'n239'},
#  {'label': 'match', 'score_id': 'n242', 'performance_id': 'n241'},
#  {'label': 'match', 'score_id': 'n243', 'performance_id': 'n242'},
#  {'label': 'match', 'score_id': 'n244', 'performance_id': 'n243'},
#  {'label': 'match', 'score_id': 'n245', 'performance_id': 'n245'},
#  {'label': 'match', 'score_id': 'n246', 'performance_id': 'n244'},
#  {'label': 'match', 'score_id': 'n247', 'performance_id': 'n246'},
#  {'label': 'match', 'score_id': 'n248', 'performance_id': 'n248'},
#  {'label': 'match', 'score_id': 'n249', 'performance_id': 'n247'},
#  {'label': 'match', 'score_id': 'n250', 'performance_id': 'n249'},
#  {'label': 'match', 'score_id': 'n251', 'performance_id': 'n252'},
#  {'label': 'match', 'score_id': 'n252', 'performance_id': 'n251'},
#  {'label': 'match', 'score_id': 'n253', 'performance_id': 'n250'},
#  {'label': 'match', 'score_id': 'n254', 'performance_id': 'n253'},
#  {'label': 'match', 'score_id': 'n255', 'performance_id': 'n254'},
#  {'label': 'match', 'score_id': 'n256', 'performance_id': 'n255'},
#  {'label': 'match', 'score_id': 'n257', 'performance_id': 'n256'},
#  {'label': 'match', 'score_id': 'n258', 'performance_id': 'n259'},
#  {'label': 'match', 'score_id': 'n259', 'performance_id': 'n258'},
#  {'label': 'match', 'score_id': 'n260', 'performance_id': 'n257'},
#  {'label': 'match', 'score_id': 'n261', 'performance_id': 'n260'},
#  {'label': 'match', 'score_id': 'n262', 'performance_id': 'n262'},
#  {'label': 'match', 'score_id': 'n263', 'performance_id': 'n261'},
#  {'label': 'match', 'score_id': 'n264', 'performance_id': 'n263'},
#  {'label': 'match', 'score_id': 'n265', 'performance_id': 'n264'},
#  {'label': 'match', 'score_id': 'n266', 'performance_id': 'n265'},
#  {'label': 'match', 'score_id': 'n267', 'performance_id': 'n266'},
#  {'label': 'match', 'score_id': 'n268', 'performance_id': 'n267'},
#  {'label': 'match', 'score_id': 'n269', 'performance_id': 'n268'},
#  {'label': 'match', 'score_id': 'n270', 'performance_id': 'n270'},
#  {'label': 'match', 'score_id': 'n271', 'performance_id': 'n271'},
#  {'label': 'match', 'score_id': 'n272', 'performance_id': 'n269'},
#  {'label': 'match', 'score_id': 'n273', 'performance_id': 'n272'},
#  {'label': 'match', 'score_id': 'n274', 'performance_id': 'n274'},
#  {'label': 'match', 'score_id': 'n275', 'performance_id': 'n275'},
#  {'label': 'match', 'score_id': 'n276', 'performance_id': 'n273'},
#  {'label': 'match', 'score_id': 'n277', 'performance_id': 'n276'},
#  {'label': 'match', 'score_id': 'n278', 'performance_id': 'n277'},
#  {'label': 'match', 'score_id': 'n279', 'performance_id': 'n278'},
#  {'label': 'match', 'score_id': 'n280', 'performance_id': 'n279'},
#  {'label': 'match', 'score_id': 'n281', 'performance_id': 'n281'},
#  {'label': 'match', 'score_id': 'n282', 'performance_id': 'n282'},
#  {'label': 'match', 'score_id': 'n283', 'performance_id': 'n280'},
#  {'label': 'match', 'score_id': 'n284', 'performance_id': 'n283'},
#  {'label': 'match', 'score_id': 'n285', 'performance_id': 'n285'},
#  {'label': 'match', 'score_id': 'n286', 'performance_id': 'n284'},
#  {'label': 'match', 'score_id': 'n287', 'performance_id': 'n287'},
#  {'label': 'match', 'score_id': 'n288', 'performance_id': 'n288'},
#  {'label': 'match', 'score_id': 'n289', 'performance_id': 'n286'},
#  {'label': 'match', 'score_id': 'n290', 'performance_id': 'n289'},
#  {'label': 'match', 'score_id': 'n291', 'performance_id': 'n290'},
#  {'label': 'match', 'score_id': 'n292', 'performance_id': 'n291'},
#  {'label': 'match', 'score_id': 'n293', 'performance_id': 'n293'},
#  {'label': 'match', 'score_id': 'n294', 'performance_id': 'n292'},
#  {'label': 'match', 'score_id': 'n295', 'performance_id': 'n294'},
#  {'label': 'match', 'score_id': 'n296', 'performance_id': 'n296'},
#  {'label': 'match', 'score_id': 'n297', 'performance_id': 'n297'},
#  {'label': 'match', 'score_id': 'n298', 'performance_id': 'n295'},
#  {'label': 'match', 'score_id': 'n299', 'performance_id': 'n298'},
#  {'label': 'match', 'score_id': 'n300', 'performance_id': 'n300'},
#  {'label': 'match', 'score_id': 'n301', 'performance_id': 'n299'},
#  {'label': 'match', 'score_id': 'n302', 'performance_id': 'n301'},
#  {'label': 'match', 'score_id': 'n303', 'performance_id': 'n302'},
#  {'label': 'match', 'score_id': 'n304', 'performance_id': 'n303'},
#  {'label': 'match', 'score_id': 'n305', 'performance_id': 'n304'},
#  {'label': 'match', 'score_id': 'n306', 'performance_id': 'n307'},
#  {'label': 'match', 'score_id': 'n307', 'performance_id': 'n305'},
#  {'label': 'match', 'score_id': 'n308', 'performance_id': 'n306'},
#  {'label': 'match', 'score_id': 'n309', 'performance_id': 'n309'},
#  {'label': 'match', 'score_id': 'n310', 'performance_id': 'n310'},
#  {'label': 'match', 'score_id': 'n311', 'performance_id': 'n308'},
#  {'label': 'match', 'score_id': 'n312', 'performance_id': 'n311'},
#  {'label': 'match', 'score_id': 'n313', 'performance_id': 'n313'},
#  {'label': 'match', 'score_id': 'n314', 'performance_id': 'n312'},
#  {'label': 'match', 'score_id': 'n315', 'performance_id': 'n314'},
#  {'label': 'match', 'score_id': 'n316', 'performance_id': 'n315'},
#  {'label': 'match', 'score_id': 'n317', 'performance_id': 'n316'},
#  {'label': 'match', 'score_id': 'n318', 'performance_id': 'n318'},
#  {'label': 'match', 'score_id': 'n319', 'performance_id': 'n317'},
#  {'label': 'match', 'score_id': 'n320', 'performance_id': 'n319'},
#  {'label': 'match', 'score_id': 'n321', 'performance_id': 'n322'},
#  {'label': 'match', 'score_id': 'n322', 'performance_id': 'n321'},
#  {'label': 'match', 'score_id': 'n323', 'performance_id': 'n320'},
#  {'label': 'match', 'score_id': 'n324', 'performance_id': 'n325'},
#  {'label': 'match', 'score_id': 'n325', 'performance_id': 'n324'},
#  {'label': 'match', 'score_id': 'n326', 'performance_id': 'n323'},
#  {'label': 'match', 'score_id': 'n327', 'performance_id': 'n326'},
#  {'label': 'match', 'score_id': 'n328', 'performance_id': 'n332'},
#  {'label': 'match', 'score_id': 'n329', 'performance_id': 'n328'},
#  {'label': 'match', 'score_id': 'n330', 'performance_id': 'n327'},
#  {'label': 'match', 'score_id': 'n331', 'performance_id': 'n329'},
#  {'label': 'match', 'score_id': 'n332', 'performance_id': 'n330'},
#  {'label': 'match', 'score_id': 'n333', 'performance_id': 'n331'},
#  {'label': 'match', 'score_id': 'n334', 'performance_id': 'n334'},
#  {'label': 'match', 'score_id': 'n335', 'performance_id': 'n339'},
#  {'label': 'match', 'score_id': 'n336', 'performance_id': 'n335'},
#  {'label': 'match', 'score_id': 'n337', 'performance_id': 'n333'},
#  {'label': 'match', 'score_id': 'n338', 'performance_id': 'n337'},
#  {'label': 'match', 'score_id': 'n339', 'performance_id': 'n338'},
#  {'label': 'match', 'score_id': 'n340', 'performance_id': 'n336'},
#  {'label': 'match', 'score_id': 'n341', 'performance_id': 'n341'},
#  {'label': 'match', 'score_id': 'n342', 'performance_id': 'n344'},
#  {'label': 'match', 'score_id': 'n343', 'performance_id': 'n343'},
#  {'label': 'match', 'score_id': 'n344', 'performance_id': 'n340'},
#  {'label': 'match', 'score_id': 'n345', 'performance_id': 'n345'},
#  {'label': 'match', 'score_id': 'n346', 'performance_id': 'n346'},
#  {'label': 'match', 'score_id': 'n347', 'performance_id': 'n342'},
#  {'label': 'match', 'score_id': 'n348', 'performance_id': 'n347'},
#  {'label': 'match', 'score_id': 'n349', 'performance_id': 'n350'},
#  {'label': 'match', 'score_id': 'n350', 'performance_id': 'n351'},
#  {'label': 'match', 'score_id': 'n351', 'performance_id': 'n348'},
#  {'label': 'match', 'score_id': 'n352', 'performance_id': 'n349'},
#  {'label': 'match', 'score_id': 'n353', 'performance_id': 'n353'},
#  {'label': 'match', 'score_id': 'n354', 'performance_id': 'n352'},
#  {'label': 'match', 'score_id': 'n355', 'performance_id': 'n354'},
#  {'label': 'deletion', 'score_id': 'n356'},
#  {'label': 'match', 'score_id': 'n357', 'performance_id': 'n358'},
#  {'label': 'match', 'score_id': 'n358', 'performance_id': 'n355'},
#  {'label': 'deletion', 'score_id': 'n359'},
#  {'label': 'match', 'score_id': 'n360', 'performance_id': 'n357'},
#  {'label': 'match', 'score_id': 'n361', 'performance_id': 'n356'},
#  {'label': 'match', 'score_id': 'n362', 'performance_id': 'n359'},
#  {'label': 'match', 'score_id': 'n363', 'performance_id': 'n364'},
#  {'label': 'match', 'score_id': 'n364', 'performance_id': 'n361'},
#  {'label': 'match', 'score_id': 'n365', 'performance_id': 'n360'},
#  {'label': 'match', 'score_id': 'n366', 'performance_id': 'n362'},
#  {'label': 'match', 'score_id': 'n367', 'performance_id': 'n363'},
#  {'label': 'match', 'score_id': 'n368', 'performance_id': 'n365'},
#  {'label': 'match', 'score_id': 'n369', 'performance_id': 'n367'},
#  {'label': 'match', 'score_id': 'n370', 'performance_id': 'n369'},
#  {'label': 'match', 'score_id': 'n371', 'performance_id': 'n368'},
#  {'label': 'match', 'score_id': 'n372', 'performance_id': 'n366'},
#  {'label': 'match', 'score_id': 'n373', 'performance_id': 'n370'},
#  {'label': 'match', 'score_id': 'n374', 'performance_id': 'n372'},
#  {'label': 'match', 'score_id': 'n375', 'performance_id': 'n371'},
#  {'label': 'match', 'score_id': 'n376', 'performance_id': 'n373'},
#  {'label': 'match', 'score_id': 'n377', 'performance_id': 'n378'},
#  {'label': 'match', 'score_id': 'n378', 'performance_id': 'n374'},
#  {'label': 'match', 'score_id': 'n379', 'performance_id': 'n375'},
#  {'label': 'match', 'score_id': 'n380', 'performance_id': 'n377'},
#  {'label': 'match', 'score_id': 'n381', 'performance_id': 'n379'},
#  {'label': 'match', 'score_id': 'n382', 'performance_id': 'n376'},
#  {'label': 'match', 'score_id': 'n383', 'performance_id': 'n380'},
#  {'label': 'match', 'score_id': 'n384', 'performance_id': 'n381'},
#  {'label': 'match', 'score_id': 'n385', 'performance_id': 'n382'},
#  {'label': 'match', 'score_id': 'n386', 'performance_id': 'n383'},
#  {'label': 'match', 'score_id': 'n387', 'performance_id': 'n384'},
#  {'label': 'match', 'score_id': 'n388', 'performance_id': 'n385'},
#  {'label': 'match', 'score_id': 'n389', 'performance_id': 'n386'},
#  {'label': 'match', 'score_id': 'n390', 'performance_id': 'n387'},
#  {'label': 'match', 'score_id': 'n391', 'performance_id': 'n388'},
#  {'label': 'match', 'score_id': 'n392', 'performance_id': 'n389'},
#  {'label': 'match', 'score_id': 'n393', 'performance_id': 'n390'},
#  {'label': 'match', 'score_id': 'n394', 'performance_id': 'n391'},
#  {'label': 'match', 'score_id': 'n395', 'performance_id': 'n392'},
#  {'label': 'match', 'score_id': 'n396', 'performance_id': 'n393'},
#  {'label': 'match', 'score_id': 'n397', 'performance_id': 'n394'},
#  {'label': 'match', 'score_id': 'n398', 'performance_id': 'n395'},
#  {'label': 'match', 'score_id': 'n399', 'performance_id': 'n396'},
#  {'label': 'match', 'score_id': 'n400', 'performance_id': 'n397'},
#  {'label': 'match', 'score_id': 'n401', 'performance_id': 'n398'},
#  {'label': 'match', 'score_id': 'n402', 'performance_id': 'n399'},
#  {'label': 'match', 'score_id': 'n403', 'performance_id': 'n400'},
#  {'label': 'match', 'score_id': 'n404', 'performance_id': 'n401'},
#  {'label': 'match', 'score_id': 'n405', 'performance_id': 'n402'},
#  {'label': 'match', 'score_id': 'n406', 'performance_id': 'n403'},
#  {'label': 'match', 'score_id': 'n407', 'performance_id': 'n404'},
#  {'label': 'match', 'score_id': 'n408', 'performance_id': 'n405'},
#  {'label': 'match', 'score_id': 'n409', 'performance_id': 'n406'},
#  {'label': 'match', 'score_id': 'n410', 'performance_id': 'n407'},
#  {'label': 'match', 'score_id': 'n411', 'performance_id': 'n408'},
#  {'label': 'match', 'score_id': 'n412', 'performance_id': 'n409'},
#  {'label': 'match', 'score_id': 'n413', 'performance_id': 'n410'},
#  {'label': 'match', 'score_id': 'n414', 'performance_id': 'n412'},
#  {'label': 'match', 'score_id': 'n415', 'performance_id': 'n411'},
#  {'label': 'match', 'score_id': 'n416', 'performance_id': 'n413'},
#  {'label': 'match', 'score_id': 'n417', 'performance_id': 'n414'},
#  {'label': 'match', 'score_id': 'n418', 'performance_id': 'n416'},
#  {'label': 'match', 'score_id': 'n419', 'performance_id': 'n415'},
#  {'label': 'match', 'score_id': 'n420', 'performance_id': 'n417'},
#  {'label': 'match', 'score_id': 'n421', 'performance_id': 'n418'},
#  {'label': 'match', 'score_id': 'n422', 'performance_id': 'n419'},
#  {'label': 'match', 'score_id': 'n423', 'performance_id': 'n421'},
#  {'label': 'match', 'score_id': 'n424', 'performance_id': 'n420'},
#  {'label': 'match', 'score_id': 'n425', 'performance_id': 'n423'},
#  {'label': 'match', 'score_id': 'n426', 'performance_id': 'n424'},
#  {'label': 'match', 'score_id': 'n427', 'performance_id': 'n422'},
#  {'label': 'match', 'score_id': 'n428', 'performance_id': 'n425'},
#  {'label': 'match', 'score_id': 'n429', 'performance_id': 'n427'},
#  {'label': 'match', 'score_id': 'n430', 'performance_id': 'n426'},
#  {'label': 'match', 'score_id': 'n431', 'performance_id': 'n428'},
#  {'label': 'match', 'score_id': 'n432', 'performance_id': 'n429'},
#  {'label': 'match', 'score_id': 'n433', 'performance_id': 'n430'},
#  {'label': 'match', 'score_id': 'n434', 'performance_id': 'n432'},
#  {'label': 'match', 'score_id': 'n435', 'performance_id': 'n431'},
#  {'label': 'match', 'score_id': 'n436', 'performance_id': 'n434'},
#  {'label': 'match', 'score_id': 'n437', 'performance_id': 'n433'},
#  {'label': 'match', 'score_id': 'n438', 'performance_id': 'n436'},
#  {'label': 'match', 'score_id': 'n439', 'performance_id': 'n435'},
#  {'label': 'match', 'score_id': 'n440', 'performance_id': 'n438'},
#  {'label': 'match', 'score_id': 'n441', 'performance_id': 'n437'},
#  {'label': 'match', 'score_id': 'n442', 'performance_id': 'n440'},
#  {'label': 'match', 'score_id': 'n443', 'performance_id': 'n439'},
#  {'label': 'match', 'score_id': 'n444', 'performance_id': 'n441'},
#  {'label': 'match', 'score_id': 'n445', 'performance_id': 'n442'},
#  {'label': 'match', 'score_id': 'n446', 'performance_id': 'n443'},
#  {'label': 'match', 'score_id': 'n447', 'performance_id': 'n444'},
#  {'label': 'match', 'score_id': 'n448', 'performance_id': 'n445'},
#  {'label': 'match', 'score_id': 'n449', 'performance_id': 'n446'},
#  {'label': 'match', 'score_id': 'n450', 'performance_id': 'n447'},
#  {'label': 'match', 'score_id': 'n451', 'performance_id': 'n450'},
#  {'label': 'match', 'score_id': 'n452', 'performance_id': 'n451'},
#  {'label': 'match', 'score_id': 'n453', 'performance_id': 'n449'},
#  {'label': 'deletion', 'score_id': 'n454'}]

# %% [markdown]
# ## File export

# %%
pt.save_musicxml(part, "musicxml_out.xml")

# %%
pt.save_performance_midi(performance[0], "midi_out.mid")

# %% [markdown]
# ### Some more imports for further processing

# %%
from partitura.musicanalysis.performance_codec import (encode_performance,
                                                        get_unique_onset_idxs,
                                                        notewise_to_onsetwise)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## A slightly more involved usage example

# %%
def match2tempo(match_path):
    """
    computes tempo curve from a match file.

    Parameters
    ----------
    match_path : string
        a path of a match file
    
    Returns
    -------
    tempo_curve_and_onsets : numpy array
        score onsets and corresponding tempo curve stacked as columns
    """

    perf, alignment, scor = pt.load_match(match_path, create_score=True)
    ppart, part = perf[0], scor[0]
    ppart.sustain_pedal_threshold = 128
    
    targets, snote_ids, ux = encode_performance(part, ppart, alignment, return_u_onset_idx=True)  
  
    nid_dict = dict((n.id, i) for i, n in enumerate(part.notes_tied))
    matched_subset_idxs = np.array([nid_dict[nid] for nid in snote_ids])       

    score_onsets = part.note_array()[matched_subset_idxs]['onset_beat'] # changed from onset_beat
    unique_onset_idxs, uni = get_unique_onset_idxs(score_onsets, return_unique_onsets=True)

    tmp_crv = notewise_to_onsetwise(np.array([targets["beat_period"]]).T, unique_onset_idxs)  
    tempo_curve_and_onsets = np.column_stack((uni, tmp_crv))

    return tempo_curve_and_onsets

# %%
te = match2tempo("example_data\\Chopin_op10_no3_p01.match")

# %%
plt.plot(te[:,0], 60/te[:,1])
